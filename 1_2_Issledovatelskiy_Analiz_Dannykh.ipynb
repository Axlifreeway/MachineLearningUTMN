# %% [markdown]
# # Набор данных
#
# **Оценка стоимости  и типа трансмиссии по данным продаж автомобилей на вторичном рынке Молдавии**

# %% [markdown]
# Набор данных представляет собой статистику параметров автомобилей на вторичном рынке в Молдавии.
#
# Набор включает ряд категориальных и численных значений, составляющих одну запись (строку). Число записей можно найти как число строк.
#
# Каждый столбец в записи — это отдельный параметр.
#
# Среди указанных параметров приведены целевой для задачи предсказания (регрессии) - цена автомобиля.
#
#  Также среди параметров есть целевой для задачи классификации - тип трансмиссии.
#
#  Последняя задача может быть рассмотрена, например, как пример задачи на заполнение пропусков (если продавец не указал соответствующий параметр).

# %% [markdown]
# # Import библиотек

# %%
import pandas as pd
from google.colab import files 

import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns; sns.set()

# %% [markdown]
# # Загрузка данных на Google Drive

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24d7475d-fe85-4df0-b0d1-0890eef4709c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24d7475d-fe85-4df0-b0d1-0890eef4709c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cars_moldova_no_dup.csv to cars_moldova_no_dup.csv

# %% [markdown]
# # Считываем файл в DataFrame

# %% [markdown]
# метод .read_csv(path,delimiter)

# %%
df = pd.read_csv('/content/cars_moldova_no_dup.csv', delimiter = ',')
df
# Out:
#              Make         Model  Year  ...     Fuel_type  Transmission  Price(euro)
# 0          Toyota         Prius  2011  ...        Hybrid     Automatic       7750.0
# 1         Renault  Grand Scenic  2014  ...        Diesel        Manual       8550.0
# 2      Volkswagen          Golf  1998  ...        Petrol        Manual       2200.0
# 3         Renault        Laguna  2012  ...        Diesel        Manual       6550.0
# 4            Opel         Astra  2006  ...  Metan/Propan        Manual       4100.0
# ...           ...           ...   ...  ...           ...           ...          ...
# 37259  Land Rover    Freelander  2002  ...  Metan/Propan        Manual       4400.0
# 37260       Dacia     Logan Mcv  2015  ...        Diesel        Manual       7000.0
# 37261     Renault         Modus  2009  ...        Diesel        Manual       4500.0
# 37262       Mazda             6  2006  ...        Diesel        Manual       4000.0
# 37263     Renault  Grand Scenic  2006  ...        Diesel        Manual       4000.0
#
# [37264 rows x 9 columns]

# %% [markdown]
# # EDA - Разведывательный анализ данных.
#
# Цель разведывательного анализа данных - попытка предварительного понимания того, с чем вы имеете дело. Например, результатами анализа могут быть удаление аномалий, заполнение (удаление) пропусков, визуализация данных, выделение признаков или получение (или преобразование) новых признаков, удаление некоторых шумов, помех или других нерегулярных значений.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37264 entries, 0 to 37263
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  37264 non-null  object
#  1   Model                 37264 non-null  object
#  2   Year                  37264 non-null  int64
#  3   Style                 37264 non-null  object
#  4   Distance              37264 non-null  float64
#  5   Engine_capacity(cm3)  37264 non-null  float64
#  6   Fuel_type             37264 non-null  object
#  7   Transmission          37264 non-null  object
#  8   Price(euro)           37264 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.6+ MB

# %% [markdown]
# посмотрим на то, какие у нас есть категориальные и численные столбцы

# %%
cat_columns = []
num_columns = []

for column_name in df.columns:
    if (df[column_name].dtypes == object):
        cat_columns +=[column_name]
    else:
        num_columns +=[column_name]

print('Категориальные данные:\t ',cat_columns, '\n Число столблцов = ',len(cat_columns))

print('Числовые данные:\t ',  num_columns, '\n Число столблцов = ',len(num_columns))
# Out:
# Категориальные данные:	  ['Make', 'Model', 'Style', 'Fuel_type', 'Transmission']
#  Число столблцов =  5
# Числовые данные:	  ['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)']
#  Число столблцов =  4

# %% [markdown]
# ## Анализ числовых признаков

# %% [markdown]
# Статистика по числовым данным

# %%
df.describe()
# Out:
#                Year      Distance  Engine_capacity(cm3)   Price(euro)
# count  37264.000000  3.726400e+04          37264.000000  3.726400e+04
# mean    2007.709264  4.758488e+05           1858.932535  9.569387e+03
# std        8.295806  4.591520e+06            707.662731  5.283315e+04
# min     1900.000000  0.000000e+00              0.000000  1.000000e+00
# 25%     2004.000000  9.000000e+04           1499.000000  3.300000e+03
# 50%     2009.000000  1.700000e+05           1800.000000  6.490000e+03
# 75%     2014.000000  2.300000e+05           2000.000000  1.179900e+04
# max     2021.000000  1.000000e+08           9999.000000  1.000000e+07

# %% [markdown]
# рассмотрим гистограммы (распределение) значений по каждому числовому признаку (столбцу)

# %%
width = 2
height = int(np.ceil(len(num_columns)/width))
fig, ax = plt.subplots(nrows=height, ncols=width, figsize=(16,8))

for idx, column_name in enumerate(num_columns):

    plt.subplot(height,width, idx+1)
    sns.histplot(data=df,
            x=column_name, bins = 20);

# %% [markdown]
# Столбцы имеют явные аномалии, особенно Distance и Price(euro). Чтобы лучше понять эти аномалии посмотрим на столбцы в логарифмическом масштабе.

# %%
plt.figure(figsize=(15,6))
sns.histplot(data=df,
        x='Price(euro)', bins = 20, log_scale = True);

# %%
# Удалим те объекты у которых Расстояние равно 0
question_dist = df[df.Distance == 0]
df = df.drop(question_dist.index)

plt.figure(figsize=(15,6))
sns.histplot(data=df,
        x='Distance', bins = 20, log_scale = True);

# %% [markdown]
# Теперь мы можем определить, что нам требуется, чтобы почистить столбцы.
#
# Также, так как задача хорошо интерпретируема мы можем почистить столбцы пользуясь здравым смыслом.
#
# Например, мы можем удалить записи, где цена меньше 100 евро или пробег меньше 1000 км и год старый.

# %%
# здравый смысл
question_dist = df[(df.Year <2021) & (df.Distance < 1100)]
df = df.drop(question_dist.index)

# анализ гистограмм
question_dist = df[(df.Distance > 1e6)]
df = df.drop(question_dist.index)

# здравый смысл
question_engine = df[df["Engine_capacity(cm3)"] < 200]
df = df.drop(question_engine.index)

# здравый смысл
question_engine = df[df["Engine_capacity(cm3)"] > 5000]
df = df.drop(question_engine.index)

# здравый смысл
question_price = df[df["Price(euro)"] < 101]
df = df.drop(question_price.index)

# анализ гистограмм
question_price = df[df["Price(euro)"] > 1e5]
df = df.drop(question_price.index)

#анализ гистограмм
question_year = df[df.Year < 1971]
df = df.drop(question_year.index)

df = df.reset_index(drop=True)
df.tail()
# Out:
#              Make         Model  Year  ...     Fuel_type  Transmission  Price(euro)
# 32529  Volkswagen        Passat  2016  ...        Petrol     Automatic      11500.0
# 32530  Land Rover    Freelander  2002  ...  Metan/Propan        Manual       4400.0
# 32531       Dacia     Logan Mcv  2015  ...        Diesel        Manual       7000.0
# 32532       Mazda             6  2006  ...        Diesel        Manual       4000.0
# 32533     Renault  Grand Scenic  2006  ...        Diesel        Manual       4000.0
#
# [5 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32534 entries, 0 to 32533
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  32534 non-null  object
#  1   Model                 32534 non-null  object
#  2   Year                  32534 non-null  int64
#  3   Style                 32534 non-null  object
#  4   Distance              32534 non-null  float64
#  5   Engine_capacity(cm3)  32534 non-null  float64
#  6   Fuel_type             32534 non-null  object
#  7   Transmission          32534 non-null  object
#  8   Price(euro)           32534 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# Посмотрим на результат

# %%
width = 2
height = int(np.ceil(len(num_columns)/width))
fig, ax = plt.subplots(nrows=height, ncols=width, figsize=(16,8))

for idx, column_name in enumerate(num_columns):

    plt.subplot(height,width, idx+1)
    sns.histplot(data=df,
            x=column_name, bins = 20);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32534 entries, 0 to 32533
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  32534 non-null  object
#  1   Model                 32534 non-null  object
#  2   Year                  32534 non-null  int64
#  3   Style                 32534 non-null  object
#  4   Distance              32534 non-null  float64
#  5   Engine_capacity(cm3)  32534 non-null  float64
#  6   Fuel_type             32534 non-null  object
#  7   Transmission          32534 non-null  object
#  8   Price(euro)           32534 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# **Зависимости параметров друг от друга**

# %%
sns.pairplot(data = df, hue ='Transmission');

# %% [markdown]
# ### Добавление колонки
# Зная суть или модель данных, мы можем предположить, чего нам не хватает - то есть попробовать добавить новый признак в данные. Такую операцию можно провести по-разному. В данном случае мы сделаем это исходя из логики. Введем признак пробег в год. \

# %%
df['km_year'] = df.Distance / (2022 - df.Year)
question_km_year = df[df.km_year > 50e3]
df = df.drop(question_km_year.index)
question_km_year = df[df.km_year < 100]
df = df.drop(question_km_year.index)
df = df.reset_index(drop=True)


plt.figure(figsize=(10,7))
sns.histplot(data=df,
            x='km_year', bins = 20);

# %% [markdown]
# Отметим, что важно, чтобы новый признак был независим от других - иначе его потом придется удалить.

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(    
    data=df,
    x="km_year", y="Distance",
    hue="Transmission", 
    size = "Price(euro)", alpha = 0.7
    );

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(    
    data=df,
    x="km_year", y="Year",
    hue="Transmission", 
    size = "Price(euro)", alpha = 0.7
    );

# %% [markdown]
# ### Удаление аномалий и связанных признаков.
# Часто проведенного выше анализа данных бывает недостаточно. Помимо всего выше изложенного бывает необходимо удаление аномалий из данных.

# %% [markdown]
# Посмотрим на аномалии с использованием т.н. boxplot - метода

# %%
num_columns.append('km_year')
num_columns
# Out:
# ['Year', 'Distance', 'Engine_capacity(cm3)', 'Price(euro)', 'km_year']

# %%
fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(10,20))

for idx, column_name in enumerate(num_columns):

    plt.subplot(5,1, idx+1)
    sns.boxplot(data=df,
            x=column_name);

# %%
question_dist = df[(df.Distance > 0.5e6)]
df = df.drop(question_dist.index)

df = df.reset_index(drop=True)

fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(10,20))

for idx, column_name in enumerate(num_columns):

    plt.subplot(5,1, idx+1)
    sns.boxplot(data=df,
            x=column_name);

# %% [markdown]
# Посмотрим на корреляцию численных столбцов

# %%
cm = sns.color_palette("vlag", as_cmap=True)

df.corr().style.background_gradient(cmap=cm, vmin = -1, vmax=1)
# Out:
# <style  type="text/css" >
# #T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col0,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col1,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col2,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col3,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col4{
#             background-color:  #a9373b;
#             color:  #f1f1f1;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col1,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col0{
#             background-color:  #a8b7cf;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col2,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col0{
#             background-color:  #f9f5f5;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col3,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col0{
#             background-color:  #cf8e8b;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col4,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col0{
#             background-color:  #d8a3a0;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col2,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col1{
#             background-color:  #f8edeb;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col3,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col1{
#             background-color:  #b8c3d5;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col4,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col1{
#             background-color:  #d7a29f;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col3,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col2{
#             background-color:  #dcaeab;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col4,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col2{
#             background-color:  #faf5f5;
#             color:  #000000;
#         }#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col4,#T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col3{
#             background-color:  #efdad8;
#             color:  #000000;
#         }</style><table id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >Distance</th>        <th class="col_heading level0 col2" >Engine_capacity(cm3)</th>        <th class="col_heading level0 col3" >Price(euro)</th>        <th class="col_heading level0 col4" >km_year</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002level0_row0" class="row_heading level0 row0" >Year</th>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col1" class="data row0 col1" >-0.431808</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col2" class="data row0 col2" >-0.026269</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col3" class="data row0 col3" >0.551700</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row0_col4" class="data row0 col4" >0.443895</td>
#             </tr>
#             <tr>
#                         <th id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002level0_row1" class="row_heading level0 row1" >Distance</th>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col0" class="data row1 col0" >-0.431808</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col2" class="data row1 col2" >0.073667</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col3" class="data row1 col3" >-0.358394</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row1_col4" class="data row1 col4" >0.446684</td>
#             </tr>
#             <tr>
#                         <th id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002level0_row2" class="row_heading level0 row2" >Engine_capacity(cm3)</th>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col0" class="data row2 col0" >-0.026269</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col1" class="data row2 col1" >0.073667</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col3" class="data row2 col3" >0.383766</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row2_col4" class="data row2 col4" >-0.010049</td>
#             </tr>
#             <tr>
#                         <th id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002level0_row3" class="row_heading level0 row3" >Price(euro)</th>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col0" class="data row3 col0" >0.551700</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col1" class="data row3 col1" >-0.358394</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col2" class="data row3 col2" >0.383766</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row3_col4" class="data row3 col4" >0.164468</td>
#             </tr>
#             <tr>
#                         <th id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002level0_row4" class="row_heading level0 row4" >km_year</th>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col0" class="data row4 col0" >0.443895</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col1" class="data row4 col1" >0.446684</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col2" class="data row4 col2" >-0.010049</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col3" class="data row4 col3" >0.164468</td>
#                         <td id="T_64fd8dcc_50d2_11ec_8f74_0242ac1c0002row4_col4" class="data row4 col4" >1.000000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Категориальные данные
# посмотрим на число повторений результата в каждом категориальном признаке

# %%
df[cat_columns].nunique()
# Out:
# Make             78
# Model           777
# Style            12
# Fuel_type         6
# Transmission      2
# dtype: int64

# %% [markdown]
# Оказалось, что часть из наших признаков имеют слишком много записей. Вероятно, редкие из них можно исключить без потери точности. Мы сделаем эту операцию объявив такие записи одним типом - rare.

# %%
counts = df.Make.value_counts()

counts
# Out:
# Volkswagen    3396
# Toyota        3066
# Mercedes      2993
# BMW           2582
# Renault       2344
#               ...
# Groz             1
# Saturn           1
# Changan          1
# Pontiac          1
# Zotye            1
# Name: Make, Length: 78, dtype: int64

# %%
counts.median()
# Out:
# 32.5

# %%
counts[counts<100]
# Out:
# Rover               90
# Chrysler            83
# Jeep                77
# Mini                72
# Infiniti            67
# Jaguar              64
# Daewoo              63
# Lincoln             49
# Dodge               49
# Alfa Romeo          38
# Smart               33
# Ssangyong           32
# GAZ                 30
# Moskvich / Izh      29
# Daihatsu            25
# UAZ                 21
# Chery               18
# Great Wall          17
# Lancia              17
# Cadillac            16
# Saab                15
# Byd                 14
# Brilliance          14
# Acura               14
# Alta marca          13
# Zaz                 11
# Lifan               10
# Lada                 9
# Isuzu                6
# Ravon                5
# LuAZ                 5
# GMC                  5
# Buick                5
# Maserati             4
# Geely                3
# Hummer               3
# Scion                3
# Datsun               3
# Tesla                3
# Haima                3
# Mercedes-Maybach     2
# Faw                  2
# ARO                  2
# Abarth               1
# Tata                 1
# Groz                 1
# Saturn               1
# Changan              1
# Pontiac              1
# Zotye                1
# Name: Make, dtype: int64

# %%
rare =  counts[(counts.values < 25)]
df['Make'] = df['Make'].replace(rare.index.values, 'Rare')
df.Make.value_counts()
# Out:
# Volkswagen        3396
# Toyota            3066
# Mercedes          2993
# BMW               2582
# Renault           2344
# Opel              1812
# Skoda             1726
# Audi              1538
# Ford              1341
# Dacia             1336
# Nissan            1252
# Hyundai           1216
# Honda              887
# KIA                654
# Mitsubishi         611
# Lexus              595
# Volvo              574
# Vaz                461
# Mazda              437
# Peugeot            387
# Chevrolet          321
# Citroen            295
# Land Rover         285
# Rare               250
# Seat               239
# Porsche            190
# Fiat               183
# Suzuki             152
# Subaru             150
# Rover               90
# Chrysler            83
# Jeep                77
# Mini                72
# Infiniti            67
# Jaguar              64
# Daewoo              63
# Lincoln             49
# Dodge               49
# Alfa Romeo          38
# Smart               33
# Ssangyong           32
# GAZ                 30
# Moskvich / Izh      29
# Daihatsu            25
# Name: Make, dtype: int64

# %%
counts = df.Model.value_counts()

counts
# Out:
# E Class      1090
# 5 Series     1030
# Passat        858
# Megane        803
# Astra         787
#              ...
# Thema           1
# Eastar          1
# Shuttle         1
# Chery Van       1
# 90              1
# Name: Model, Length: 777, dtype: int64

# %%
counts.median()
# Out:
# 9.0

# %%
counts[counts<100]
# Out:
# Clio         97
# X-Trail      93
# Juke         88
# Combo        88
# A Class      87
#              ..
# Thema         1
# Eastar        1
# Shuttle       1
# Chery Van     1
# 90            1
# Name: Model, Length: 704, dtype: int64

# %%
counts = df.Model.value_counts()
rare =  counts[(counts.values <  50)]
df['Model'] = df['Model'].replace(rare.index.values, 'Rare')
df.Model.value_counts()
# Out:
# Rare             6680
# E Class          1090
# 5 Series         1030
# Passat            858
# Megane            803
#                  ...
# Urban Cruiser      51
# Accent             51
# Vento              51
# Avensis Verso      50
# Matrix             50
# Name: Model, Length: 134, dtype: int64

# %% [markdown]
# ## Сохранение DataFrame в файл

# %% [markdown]
# Метод .to_csv(path, index)

# %%
df.to_csv('/content/cars_moldova_clean.csv',index=False)

# %% [markdown]
# # Приведение категориальных признаков к численным

# %% [markdown]
# ### Бинарные признаки

# %%
df['Transmission'] = df['Transmission'].map({'Automatic': 1, 'Manual': 0})

# %% [markdown]
# ### Кодирование многозначных признаков

# %%
df_se = df.copy()
df_se[cat_columns] = df_se[cat_columns].astype('category')

for _, column_name in enumerate(cat_columns):
    df_se[column_name] =  df_se[column_name].cat.codes
df_se.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32074 entries, 0 to 32073
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  32074 non-null  int8
#  1   Model                 32074 non-null  int16
#  2   Year                  32074 non-null  int64
#  3   Style                 32074 non-null  int8
#  4   Distance              32074 non-null  float64
#  5   Engine_capacity(cm3)  32074 non-null  float64
#  6   Fuel_type             32074 non-null  int8
#  7   Transmission          32074 non-null  int8
#  8   Price(euro)           32074 non-null  float64
#  9   km_year               32074 non-null  float64
# dtypes: float64(4), int16(1), int64(1), int8(4)
# memory usage: 1.4 MB

# %%
df_se.head()
# Out:
#    Make  Model  Year  Style  ...  Fuel_type  Transmission  Price(euro)       km_year
# 0    40     92  2011      4  ...          2             1       7750.0  17727.272727
# 1    32     62  2014     11  ...          0             0       8550.0  16875.000000
# 2    32     71  2012     11  ...          0             0       6550.0  11000.000000
# 3    28     23  2006     11  ...          3             0       4100.0  12500.000000
# 4    23    124  2000      5  ...          0             0       3490.0  13636.363636
#
# [5 rows x 10 columns]

# %%
sns.pairplot(data = df_se, hue ='Transmission');

# %% [markdown]
# ### One-hot кодирование многозначных признаков

# %%
df_ohe = df.copy()
df_ohe = pd.get_dummies(df_ohe)
df_ohe.tail()
# Out:
#        Year  Distance  ...  Fuel_type_Petrol  Fuel_type_Plug-in Hybrid
# 32069  2016   88000.0  ...                 1                         0
# 32070  2002  225000.0  ...                 0                         0
# 32071  2015   89000.0  ...                 0                         0
# 32072  2006  370000.0  ...                 0                         0
# 32073  2006  300000.0  ...                 0                         0
#
# [5 rows x 202 columns]

# %%
df_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32074 entries, 0 to 32073
# Columns: 202 entries, Year to Fuel_type_Plug-in Hybrid
# dtypes: float64(4), int64(2), uint8(196)
# memory usage: 7.5 MB

# %% [markdown]
# ### Сохранение DataFrame в файл

# %% [markdown]
# Метод .to_csv(path, index)

# %%
df_se.to_csv('/content/cars_moldova_cat_num.csv',index=False)
df_ohe.to_csv('/content/cars_moldova_onehot.csv',index=False)

# %% [markdown]
# # Контрольные вопросы

# %% [markdown]
# Вопрос:
# <b>Назовите число столбцов?
#     <br> ответ: <code> 10 len(df.columns)

# %% [markdown]
# Вопрос:
# <b>Назовите целевой столбец для задачи регрессии?
#     <br> ответ: <code> Price(euro)

# %% [markdown]
# Вопрос:
# <b>Назовите целевой столбец для задачи классификации?
#     <br> ответ: <code> Transmission

# %% [markdown]
# Вопрос:
# <b>Назовите колонку которую точно стоит убрать?
#     <br> ответ: <code> index
