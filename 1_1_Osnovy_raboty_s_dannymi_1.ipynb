# %% [markdown]
# # Набор данных
#
# **Оценка стоимости  и типа трансмиссии по данным продаж автомобилей на вторичном рынке Молдавии**

# %% [markdown]
# Набор данных представляет собой статистику параметров автомобилей на вторичном рынке в Молдавии.
#
# Набор включает ряд категориальных и численных значений, составляющих одну запись (строку). Число записей можно найти как число строк.
#
# Каждый столбец в записи — это отдельный параметр.
#
# Среди указанных параметров приведены целевой для задачи предсказания (регрессии) - цена автомобиля.
#
#  Также среди параметров есть целевой для задачи классификации - тип трансмиссии.
#
#  Последняя задача может быть рассмотрена, например, как пример задачи на заполнение пропусков (если продавец не указал соответствующий параметр).

# %% [markdown]
# # Import библиотек

# %%
import pandas as pd

from google.colab import files

# %% [markdown]
# # Загрузка данных на Google Drive

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7e065d3f-1787-406b-818c-6e56df47e151" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7e065d3f-1787-406b-818c-6e56df47e151">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cars_moldova.csv to cars_moldova.csv

# %% [markdown]
# # Считываем файл в DataFrame

# %% [markdown]
# метод .read_csv(path,delimiter)

# %%
df = pd.read_csv('/content/cars_moldova.csv', delimiter = ',')

# %%
df
# Out:
#              Make         Model  Year  ...     Fuel_type  Transmission  Price(euro)
# 0          Toyota         Prius  2011  ...        Hybrid     Automatic       7750.0
# 1         Renault  Grand Scenic  2014  ...        Diesel        Manual       8550.0
# 2      Volkswagen          Golf  1998  ...        Petrol        Manual       2200.0
# 3         Renault        Laguna  2012  ...        Diesel        Manual       6550.0
# 4            Opel         Astra  2006  ...  Metan/Propan        Manual       4100.0
# ...           ...           ...   ...  ...           ...           ...          ...
# 41002       Dacia     Logan Mcv  2015  ...        Diesel        Manual       7000.0
# 41003     Renault         Modus  2009  ...        Diesel        Manual       4500.0
# 41004    Mercedes       E Class  2016  ...        Diesel     Automatic      29500.0
# 41005       Mazda             6  2006  ...        Diesel        Manual       4000.0
# 41006     Renault  Grand Scenic  2006  ...        Diesel        Manual       4000.0
#
# [41007 rows x 9 columns]

# %% [markdown]
# # Информация о DataFrame

# %% [markdown]
# Метод .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41007 entries, 0 to 41006
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Make                  41007 non-null  object
#  1   Model                 41007 non-null  object
#  2   Year                  41007 non-null  int64
#  3   Style                 41007 non-null  object
#  4   Distance              41007 non-null  float64
#  5   Engine_capacity(cm3)  41007 non-null  float64
#  6   Fuel_type             41007 non-null  object
#  7   Transmission          41007 non-null  object
#  8   Price(euro)           41007 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 2.8+ MB

# %% [markdown]
# # Поиск Дубликатов

# %% [markdown]
# методы .duplicated() и .sum()

# %%
df.duplicated().sum()
# Out:
# 3743

# %% [markdown]
# **Удаление дубликатов**
#
# Методы .drop_duplicates() и .reset_index()

# %%
df = df.drop_duplicates()

df = df.reset_index(drop=True)

df
# Out:
#              Make         Model  Year  ...     Fuel_type  Transmission  Price(euro)
# 0          Toyota         Prius  2011  ...        Hybrid     Automatic       7750.0
# 1         Renault  Grand Scenic  2014  ...        Diesel        Manual       8550.0
# 2      Volkswagen          Golf  1998  ...        Petrol        Manual       2200.0
# 3         Renault        Laguna  2012  ...        Diesel        Manual       6550.0
# 4            Opel         Astra  2006  ...  Metan/Propan        Manual       4100.0
# ...           ...           ...   ...  ...           ...           ...          ...
# 37259  Land Rover    Freelander  2002  ...  Metan/Propan        Manual       4400.0
# 37260       Dacia     Logan Mcv  2015  ...        Diesel        Manual       7000.0
# 37261     Renault         Modus  2009  ...        Diesel        Manual       4500.0
# 37262       Mazda             6  2006  ...        Diesel        Manual       4000.0
# 37263     Renault  Grand Scenic  2006  ...        Diesel        Manual       4000.0
#
# [37264 rows x 9 columns]

# %% [markdown]
# # Индексация

# %% [markdown]
# **Визуализация части DataFrame**
#
# Метод .head(n) - первые n строк

# %%
df.head(6)
# Out:
#          Make         Model  Year  ...     Fuel_type  Transmission  Price(euro)
# 0      Toyota         Prius  2011  ...        Hybrid     Automatic       7750.0
# 1     Renault  Grand Scenic  2014  ...        Diesel        Manual       8550.0
# 2  Volkswagen          Golf  1998  ...        Petrol        Manual       2200.0
# 3     Renault        Laguna  2012  ...        Diesel        Manual       6550.0
# 4        Opel         Astra  2006  ...  Metan/Propan        Manual       4100.0
# 5    Mercedes          Vito  2000  ...        Diesel        Manual       3490.0
#
# [6 rows x 9 columns]

# %% [markdown]
# Метод .tail(n) - последние n строк

# %%
df.tail(9)
# Out:
#              Make         Model  Year  ...     Fuel_type  Transmission  Price(euro)
# 37255     Renault        Megane  2011  ...        Diesel     Automatic       6200.0
# 37256      Toyota         Auris  2007  ...        Diesel     Automatic       4444.0
# 37257       Skoda        Superb  2016  ...        Petrol     Automatic      21000.0
# 37258  Volkswagen        Passat  2016  ...        Petrol     Automatic      11500.0
# 37259  Land Rover    Freelander  2002  ...  Metan/Propan        Manual       4400.0
# 37260       Dacia     Logan Mcv  2015  ...        Diesel        Manual       7000.0
# 37261     Renault         Modus  2009  ...        Diesel        Manual       4500.0
# 37262       Mazda             6  2006  ...        Diesel        Manual       4000.0
# 37263     Renault  Grand Scenic  2006  ...        Diesel        Manual       4000.0
#
# [9 rows x 9 columns]

# %% [markdown]
# **Индексация**
#
# аттрибут .loc[строки, столбцы]

# %%
df.loc[1437,'Transmission']
# Out:
# 'Automatic'

# %%
df.loc[:,'Transmission']
# Out:
# 0        Automatic
# 1           Manual
# 2           Manual
# 3           Manual
# 4           Manual
#            ...
# 37259       Manual
# 37260       Manual
# 37261       Manual
# 37262       Manual
# 37263       Manual
# Name: Transmission, Length: 37264, dtype: object

# %%
df.loc[:,['Transmission']].head(5)
# Out:
#   Transmission
# 0    Automatic
# 1       Manual
# 2       Manual
# 3       Manual
# 4       Manual

# %%
df.loc[:,['Transmission','Year']].head(5)
# Out:
#   Transmission  Year
# 0    Automatic  2011
# 1       Manual  2014
# 2       Manual  1998
# 3       Manual  2012
# 4       Manual  2006

# %%
df.loc[:,'Make':'Style'].head(5)
# Out:
#          Make         Model  Year      Style
# 0      Toyota         Prius  2011  Hatchback
# 1     Renault  Grand Scenic  2014  Universal
# 2  Volkswagen          Golf  1998  Hatchback
# 3     Renault        Laguna  2012  Universal
# 4        Opel         Astra  2006  Universal

# %%
df.loc[69,:]
# Out:
# Make                        Honda
# Model                        CR-V
# Year                         2002
# Style                   Universal
# Distance                   275100
# Engine_capacity(cm3)         2000
# Fuel_type                  Petrol
# Transmission               Manual
# Price(euro)                  5900
# Name: 69, dtype: object

# %%
df.loc[69:69,:]
# Out:
#      Make Model  Year  ... Fuel_type  Transmission  Price(euro)
# 69  Honda  CR-V  2002  ...    Petrol        Manual       5900.0
#
# [1 rows x 9 columns]

# %%
df.loc[322:1437,:]
# Out:
#           Make     Model  Year  ...       Fuel_type  Transmission  Price(euro)
# 322      Skoda   Octavia  2010  ...          Petrol        Manual       5350.0
# 323   Mercedes   E Class  2016  ...          Diesel     Automatic      26950.0
# 324      Honda     Civic  2006  ...          Petrol        Manual       5400.0
# 325       Ford    Fusion  2015  ...  Plug-in Hybrid     Automatic      11499.0
# 326       Ford    Fusion  2003  ...          Diesel     Automatic       4100.0
# ...        ...       ...   ...  ...             ...           ...          ...
# 1433   Peugeot       208  2013  ...          Diesel     Automatic       6999.0
# 1434  Infiniti      QX30  2017  ...          Diesel     Automatic      15490.0
# 1435      Ford      Kuga  2016  ...          Diesel        Manual      14490.0
# 1436      Ford      Kuga  2018  ...          Diesel        Manual      14250.0
# 1437       BMW  3 Series  2016  ...          Petrol     Automatic      17500.0
#
# [1116 rows x 9 columns]

# %%
df.loc[227:229,'Make':'Fuel_type']
# Out:
#         Make    Model  Year  ...  Distance  Engine_capacity(cm3)     Fuel_type
# 227     Opel  Calibra  1992  ...  400000.0                2000.0  Metan/Propan
# 228  Renault   Kadjar  2016  ...  150425.0                1500.0        Diesel
# 229     Ford   Fusion  2018  ...  105000.0                2000.0        Hybrid
#
# [3 rows x 7 columns]

# %% [markdown]
# **Логическое Индексирование**

# %%
df[df['Transmission']=='Manual']
# Out:
#              Make         Model  Year  ...     Fuel_type  Transmission  Price(euro)
# 1         Renault  Grand Scenic  2014  ...        Diesel        Manual       8550.0
# 2      Volkswagen          Golf  1998  ...        Petrol        Manual       2200.0
# 3         Renault        Laguna  2012  ...        Diesel        Manual       6550.0
# 4            Opel         Astra  2006  ...  Metan/Propan        Manual       4100.0
# 5        Mercedes          Vito  2000  ...        Diesel        Manual       3490.0
# ...           ...           ...   ...  ...           ...           ...          ...
# 37259  Land Rover    Freelander  2002  ...  Metan/Propan        Manual       4400.0
# 37260       Dacia     Logan Mcv  2015  ...        Diesel        Manual       7000.0
# 37261     Renault         Modus  2009  ...        Diesel        Manual       4500.0
# 37262       Mazda             6  2006  ...        Diesel        Manual       4000.0
# 37263     Renault  Grand Scenic  2006  ...        Diesel        Manual       4000.0
#
# [20723 rows x 9 columns]

# %% [markdown]
# # Сортировка DataFrame

# %% [markdown]
# Метод .sort_values(by)

# %%
df.sort_values(by = 'Price(euro)').tail(5)
# Out:
#              Make               Model  ...  Transmission Price(euro)
# 13131      Toyota  Land Cruiser Prado  ...     Automatic    200000.0
# 14834  Volkswagen               Caddy  ...        Manual    200000.0
# 29132    Mercedes             G Class  ...     Automatic    215000.0
# 17849         KIA            Sportage  ...     Automatic    490000.0
# 33677  Brilliance                 BS3  ...        Manual  10000000.0
#
# [5 rows x 9 columns]

# %% [markdown]
# Метод .sort_values(by, ascending= False)

# %%
df.sort_values(by = 'Year', ascending= False).head(5)
# Out:
#              Make      Model  Year  ... Fuel_type  Transmission  Price(euro)
# 29164        Audi         A5  2021  ...    Petrol     Automatic      32200.0
# 32583    Mercedes  GLS Klass  2021  ...    Diesel     Automatic     107528.0
# 15611  Volkswagen       Polo  2021  ...    Petrol        Manual       1900.0
# 6044        Skoda     Superb  2021  ...    Petrol     Automatic      30000.0
# 11840      Toyota    Corolla  2021  ...    Hybrid     Automatic      23000.0
#
# [5 rows x 9 columns]

# %% [markdown]
# # Сохранение DataFrame в файл

# %% [markdown]
# Метод .to_csv(path, index)

# %%
df.to_csv('/content/cars_moldova_no_dup.csv',index=False)

# %% [markdown]
# # Контрольные вопросы

# %% [markdown]
# Вопрос:
# <b> Назовите тип данных категориальных столбцов в Pandas

# %% [markdown]
# Вопрос:
# <b>Назовите целевой столбец для задачи регрессии

# %% [markdown]
# Вопрос:
# <b>Назовите целевой столбец для задачи классификации

# %% [markdown]
# Вопрос:
# <b>Возьмите датафрейм после удаления дубликатов. Выберете из полного датафрейма строки с индекса 69 по 322. Отсортируйте полученный датафрейм по колонке  'Distance' по убыванию. Какое значение колонки  'Style' у полученного датафрейма во второй строке сверху

# %% [markdown]
# Вопрос:
# <b> Укажите правильную размерность исходного набора данных
